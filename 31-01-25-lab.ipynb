# %% [markdown]
# <a href="https://colab.research.google.com/github/Burra-Tarun-Kumar/ML_Training/blob/main/31-01-25-lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data =pd.read_csv("/content/NewspaperData.csv")

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
df_new = df[['daily','sunday']]
df_new.head()
# Out:
#      daily   sunday
# 0  391.952  488.506
# 1  516.981  798.298
# 2  355.628  235.084
# 3  238.555  299.451
# 4  537.780  559.093

# %%
import statsmodels.formula.api as smf  # Not statsmodels.api
import seaborn as sns
model=smf.ols("sunday-daily",data=df).fit
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-14-e076cec730d7> in <cell line: 0>()
#       1 import statsmodels.formula.api as smf  # Not statsmodels.api
#       2 import seaborn as sns
# ----> 3 model=smf.ols("sunday-daily",data=df).fit
#
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     201             missing = 'raise'
#     202
# --> 203         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                                   missing=missing)
#     205         ((endog, exog), missing_idx, design_info) = tmp
#
# /usr/local/lib/python3.11/dist-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ...

# %%
sns.regplot(x="daily",y="sunday",data=df)
# Out:
# <Axes: xlabel='daily', ylabel='sunday'>
